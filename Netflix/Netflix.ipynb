# %% [markdown]
# **Import the library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import iplot, plot
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# **Import file from kaggle**

# %%
from google.colab import files

# Upload kaggle.json
files.upload()
# Out:
#      <input type="file" id="files-1f13a951-c09a-441b-b06d-0b0676e4ce38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f13a951-c09a-441b-b06d-0b0676e4ce38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download ariyoomotade/netflix-data-cleaning-analysis-and-visualization
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ariyoomotade/netflix-data-cleaning-analysis-and-visualization
# License(s): CC0-1.0
# ...
#   0% 0.00/270k [00:00<?, ?B/s]
# 100% 270k/270k [00:00<00:00, 689MB/s]

# %%
#unzip the zip file from kaggle
# !unzip netflix-data-cleaning-analysis-and-visualization.zip
# Out:
# Archive:  netflix-data-cleaning-analysis-and-visualization.zip
#   inflating: netflix1.csv

# %% [markdown]
# **Loading dataset**

# %%
#load dataset
import pandas as pd

df = pd.read_csv("netflix1.csv")  # adjust filename as per the zip contents
print("First five data ")
df.head()
# Out:
# First five data
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#to show last 5 row of dataset
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
#to show any random row
df.sample(10)
# Out:
#          type                                              title  \
# 1956    Movie                                         Okko's Inn
# 7255  TV Show                            Restaurants on the Edge
# 3536    Movie                                               Ajji
# 2825    Movie  The Lonely Island Presents: The Unauthorized B...
# 6107    Movie                                        The Endless
# 622     Movie                      Cheech & Chong's Still Smokin
# 6791  TV Show                                       Love Naggers
# 3932    Movie    Norm Macdonald: Hitler's Dog, Gossip & Trickery
# 1573    Movie                                        Taxi Ballad
# 5581    Movie                                       Now and Then
#
#                            director        country date_added  release_year  \
# 1956                  Kitaro Kosaka          Japan 2020-06-12          2018
# 7255                      Not Given         Canada 2020-05-08          2020
# ...

# %%
print("Total rows-> ", df.shape[0])
print("Total rows-> ", df.shape[1])
df.shape
# Out:
# Total rows->  8790
# Total rows->  10
# (8790, 10)

# %%
# use to show each column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
#used to show mathematical computation of column having int data type
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['release_year'].plot(kind='hist', bins=20, title='release_year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['release_year'].plot(kind='line', figsize=(8, 4), title='release_year')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# **checking missing value**

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# **Checking Duplicate**

# %%
df["show_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#removing show id column only represent no of column
df.drop(columns="show_id", inplace=True)

# %%
#convet dateadded to date type
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.head(1)
# Out:
#     type                 title         director        country date_added  \
# 0  Movie  Dick Johnson Is Dead  Kirsten Johnson  United States 2021-09-25
#
#    release_year rating duration      listed_in
# 0          2020  PG-13   90 min  Documentaries

# %% [markdown]
# **Exploratory Data Analysis (EDA)**
# Checking each column one by one using univariate anlysis

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Luxembourg           1
# Senegal              1
# Belarus              1
# Puerto Rico          1
# Cyprus               1
# Name: count, Length: 86, dtype: int64

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1146
# 2019    1030
# 2017    1030
# 2020     953
# 2016     901
#         ...
# 1961       1
# 1959       1
# 1925       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
df["date_added"]
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-22
# 4      2021-09-24
#           ...
# 8785   2017-01-17
# 8786   2018-09-13
# 8787   2016-12-15
# 8788   2018-06-23
# 8789   2018-06-07
# Name: date_added, Length: 8790, dtype: datetime64[ns]

# %%
print(f"Oldest Added Date: {df['date_added'].min()}")
print(f"Newest Added Date: {df['date_added'].max()}")
# Out:
# Oldest Added Date: 2008-01-01 00:00:00
# Newest Added Date: 2021-09-25 00:00:00

# %%
released_year = df.release_year.value_counts()
released_year
# Out:
# release_year
# 2018    1146
# 2019    1030
# 2017    1030
# 2020     953
# 2016     901
#         ...
# 1961       1
# 1959       1
# 1925       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
import matplotlib.pyplot as plt
import plotly.express as px
fig = px.area(released_year, x = released_year.index, y = released_year)

iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
rating = df["rating"].value_counts()
rating
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
fig = px.bar(data_frame=rating,
             x = rating,
             y = rating.index,
             color = rating.index,
             text = rating,
             orientation= "h",
             title= "Popularity of Rating",
             labels = {
                    "x" : "Frequency",
                    "rating" : "Rating"
                },
             height=680
            )
# Custom Format of numbers
fig.update_traces(
    textposition = "outside",
    outsidetextfont = {
        "family": "consolas",
         "size": 13
    }
)

iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["duration"].value_counts()
# Out:
# duration
# 1 Season      1791
# 2 Seasons      421
# 3 Seasons      198
# 90 min         152
# 94 min         146
#               ...
# 191 min          1
# 17 Seasons       1
# 10 min           1
# 312 min          1
# 11 Seasons       1
# Name: count, Length: 220, dtype: int64
